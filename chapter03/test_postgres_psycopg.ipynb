# %%
import psycopg

DB_URL = "postgresql://langgraph_user:123456@localhost:5432/langgraph_db?sslmode=disable"

conn = psycopg.connect(DB_URL)
cur = conn.cursor()

# 查看 PostgreSQL 版本信息
cur.execute("SELECT version();")
result = cur.fetchone()
print(f"PostgreSQL 版本：{result[0]}")

cur.close()
conn.close()
# Out:
# PostgreSQL 版本：PostgreSQL 14.23 (Debian 14.23-1.pgdg13+1) on x86_64-pc-linux-gnu, compiled by gcc (Debian 14.2.0-19) 14.2.0, 64-bit
